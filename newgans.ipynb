# %%
# !pip install sdv

# %%
from sdv.tabular import CTGAN
import pandas as pd

# %%
data = pd.read_csv("C:/Users/mmrha/Desktop/cmu/Independent study/python/winemin.csv")
data.head()
# Out:
#    fixed.acidity  volatile.acidity  citric.acid  residual.sugar  chlorides  \
# 0            6.2             0.450         0.26             4.4      0.063
# 1            9.8             0.360         0.46            10.5      0.038
# 2            5.5             0.485         0.00             1.5      0.065
# 3            6.4             0.595         0.14             5.2      0.058
# 4            7.6             0.480         0.37             0.8      0.037
#
#    free.sulfur.dioxide  total.sulfur.dioxide  density    pH  sulphates  \
# 0                 63.0                 206.0   0.9940  3.27       0.52
# 1                  4.0                  83.0   0.9956  2.89       0.30
# 2                  8.0                 103.0   0.9940  3.63       0.40
# 3                 15.0                  97.0   0.9951  3.38       0.36
# 4                  4.0                 100.0   0.9902  3.03       0.39
#
#    alcohol
# 0      9.8
# 1     10.1
# 2      9.7
# 3      9.0
# 4     11.4

# %%
model = CTGAN()
model.fit(data)
# Out:
# C:\Users\mmrha\anaconda3\lib\site-packages\sklearn\utils\validation.py:72: FutureWarning: Pass n_components=10 as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   "will result in an error", FutureWarning)
# C:\Users\mmrha\anaconda3\lib\site-packages\sklearn\utils\validation.py:72: FutureWarning: Pass n_components=10 as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   "will result in an error", FutureWarning)
# C:\Users\mmrha\anaconda3\lib\site-packages\sklearn\utils\validation.py:72: FutureWarning: Pass n_components=10 as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   "will result in an error", FutureWarning)
# ...

# %%
new_data = model.sample(5000)
new_data.head()
# Out:
#    fixed.acidity  volatile.acidity  citric.acid  residual.sugar  chlorides  \
# 0            7.8             0.554         0.40            1.29   0.065302
# 1            6.6             0.373         0.37            6.47   0.062047
# 2            6.9             0.358         0.48            2.69   0.041151
# 3            6.7             0.248         0.51            2.24   0.084940
# 4            8.0             0.306         0.18            1.00   0.043686
#
#    free.sulfur.dioxide  total.sulfur.dioxide   density    pH  sulphates  \
# 0                  9.3                  50.5  0.989200  3.34       0.87
# 1                  3.0                 205.5  0.996572  2.98       0.64
# 2                 26.4                 149.5  0.995187  3.55       0.44
# 3                 39.3                 105.3  0.992294  3.09       0.36
# 4                  7.8                 118.4  0.991284  3.19       0.72
#
#    alcohol
# 0    10.52
# 1     9.60
# 2    10.26
# 3    11.58
# 4     9.15

# %%
new_data.to_csv("C:/Users/mmrha/Desktop/cmu/Independent study/python/winesyn2.csv")

# %%
data.describe()
# Out:
#            length    diameter     height  wholeweight  shuckedweight  \
# count   36.000000   36.000000  36.000000    36.000000      36.000000
# mean    98.472222   80.972222  36.027778  1751.861111     827.972222
# std     15.296099   13.291213   5.719571   488.508585     306.434378
# min     66.000000   57.000000  25.000000   803.000000     289.000000
# 25%     86.000000   68.000000  32.000000  1347.250000     624.250000
# 50%    101.000000   82.000000  36.000000  1821.000000     806.500000
# 75%    109.250000   91.250000  40.000000  2178.750000    1015.500000
# max    133.000000  110.000000  45.000000  2423.000000    1458.000000
#
#        visceraweight  shellweight
# count      36.000000    36.000000
# mean      489.638889   703.361111
# std       172.232095   183.454806
# min       218.000000   304.000000
# 25%       349.000000   523.250000
# 50%       509.000000   758.000000
# 75%       611.250000   865.250000
# max       878.000000   924.000000

# %%
new_data.describe()
# Out:
#             length     diameter       height  wholeweight  shuckedweight  \
# count  5000.000000  5000.000000  5000.000000  5000.000000    5000.000000
# mean    110.432400    82.245400    30.024800  1506.756400     552.448800
# std      17.665363    15.633863     5.400335   470.785847     288.500909
# min      66.000000    57.000000    25.000000   803.000000     289.000000
# 25%      98.000000    70.000000    25.000000  1128.750000     289.000000
# 50%     112.000000    82.000000    28.000000  1524.000000     462.000000
# 75%     126.000000    95.000000    34.000000  1850.250000     732.250000
# max     133.000000   110.000000    45.000000  2423.000000    1458.000000
#
#        visceraweight  shellweight
# count    5000.000000  5000.000000
# mean      627.939600   765.486000
# std       197.133965   157.843769
# min       218.000000   304.000000
# 25%       481.000000   686.000000
# 50%       651.000000   802.000000
# 75%       801.000000   903.000000
# ...
